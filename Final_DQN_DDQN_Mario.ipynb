# %% [markdown]
# ###Code

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install gym-super-mario-bros==7.3.0
# Out:
# Collecting gym-super-mario-bros==7.3.0
#   Downloading https://files.pythonhosted.org/packages/a0/b8/07460212c2568f78b02995834e7bdc25349e586473919e2983e01b984abf/gym_super_mario_bros-7.3.0-py2.py3-none-any.whl (198kB)
#      |████████████████████████████████| 204kB 23.0MB/s
# Collecting nes-py>=8.0.0
#   Downloading https://files.pythonhosted.org/packages/72/5e/d652644d718454947b9e26d8a145eb7d1eff0f014dceee7bd88e4894b3f3/nes_py-8.1.6.tar.gz (77kB)
#      |████████████████████████████████| 81kB 10.8MB/s
# Requirement already satisfied: gym>=0.17.2 in /usr/local/lib/python3.7/dist-packages (from nes-py>=8.0.0->gym-super-mario-bros==7.3.0) (0.17.3)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.7/dist-packages (from nes-py>=8.0.0->gym-super-mario-bros==7.3.0) (1.19.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from nes-py>=8.0.0->gym-super-mario-bros==7.3.0) (1.5.0)
# Collecting tqdm>=4.48.2
#   Downloading https://files.pythonhosted.org/packages/42/d7/f357d98e9b50346bcb6095fe3ad205d8db3174eb5edb03edfe7c4099576d/tqdm-4.61.0-py2.py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 12.5MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym>=0.17.2->nes-py>=8.0.0->gym-super-mario-bros==7.3.0) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym>=0.17.2->nes-py>=8.0.0->gym-super-mario-bros==7.3.0) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->nes-py>=8.0.0->gym-super-mario-bros==7.3.0) (0.16.0)
# Building wheels for collected packages: nes-py
#   Building wheel for nes-py (setup.py) ... done
#   Created wheel for nes-py: filename=nes_py-8.1.6-cp37-cp37m-linux_x86_64.whl size=437274 sha256=1342281227984de6ca80540a89fe11da455784a54b882aad566cfbab11bc8c4c
#   Stored in directory: /root/.cache/pip/wheels/a7/56/af/b84114d31ea6301a5c4651fb048bd6072646596a6ceb3bbc24
# Successfully built nes-py
# Installing collected packages: tqdm, nes-py, gym-super-mario-bros
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# Successfully installed gym-super-mario-bros-7.3.0 nes-py-8.1.6 tqdm-4.61.0

# %%
import gym_super_mario_bros
from nes_py.wrappers import JoypadSpace
import gym

import torch
import torch.nn as nn
import numpy as np
import cv2
import random
import collections
import matplotlib.pyplot as plt

# %%
class proc_env1(gym.Wrapper):
    def __init__(self, env=None, skip=4):
        super(proc_env1, self).__init__(env)
        self.buffer = collections.deque(maxlen=2)
        self.skip = skip

    def reset(self):
        self.buffer.clear()
        obs = self.env.reset()
        self.buffer.append(obs)
        return obs

    def step(self, action):
        tot_rew = 0.0
        done = None
        for _ in range(self.skip):
            obs, rew, done, info = self.env.step(action)
            self.buffer.append(obs)
            tot_rew += rew
            if done:
                break
        max_frame = np.max(np.stack(self.buffer), axis=0)
        return max_frame, tot_rew, done, info

class proc_env2(gym.ObservationWrapper):
    def __init__(self, env=None):
        super(proc_env2, self).__init__(env)
        self.obs_space = gym.spaces.Box(low=0.0, high=1.0, shape=(1, 84, 84),dtype=np.float32)

    def observation(self, obs):
        img = np.reshape(obs, [240, 256, 3]).astype(np.float32)
        img = img[:, :, 0] * 0.299 + img[:, :, 1] * 0.587 + img[:, :, 2] * 0.114
        resized = cv2.resize(img, (84, 110), interpolation=cv2.INTER_AREA)
        res = np.reshape(resized[18:102, :],[84, 84, 1])
        
        return np.array(np.moveaxis(res, 2, 0)) / 255.0

def proc_env(env):
    env = proc_env1(env)
    env = proc_env2(env)
    return JoypadSpace(env, [["right"], ["right", "A"], ["left"], ["left","A"]]) #, ["A"]])

# %%
class DQN(nn.Module):

    def __init__(self, input_shape, n_actions):
        super(DQN, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, n_actions)
        )

    def forward(self, x):
        conv_out = self.conv(x)
        return conv_out


class Agent:

    def __init__(self, s_space, a_space, max_mem, batch_size, erate, emin, decay, lr, gamma, ddq):

        self.dev = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.s_space = s_space
        self.a_space = a_space
        self.max_mem = max_mem
        self.mem_samp = batch_size
        self.erate = erate
        self.emin = emin
        self.decay = decay
        self.loss = nn.SmoothL1Loss().to(self.dev)
        self.gamma = gamma
        self.ddq = ddq
        self.end_pos = 0
        self.num_que = 0
        self.step = 0
        self.copy = 5000  # Change target weights every 5000 steps
        self.memory = [torch.zeros(self.max_mem, *self.s_space), torch.zeros(self.max_mem, *self.s_space),
                       torch.zeros(self.max_mem, 1),torch.zeros(self.max_mem, 1),torch.zeros(self.max_mem, 1)] #state,next_state,action,reward,done

        if self.ddq:  
            self.Q1 = DQN(s_space, a_space).to(self.dev)
            self.Q2 = DQN(s_space, a_space).to(self.dev)
        else:  
            self.Q1 = DQN(s_space, a_space).to(self.dev)

        self.optimizer = torch.optim.Adam(self.Q1.parameters(), lr=lr)

    def action(self, state,ep):       
        if random.random() < self.erate: #*(0.999**ep):  
            return torch.tensor([[random.randrange(self.a_space)]])

        if self.ddq:
            self.step += 1

        return torch.argmax(self.Q1(state.to(self.dev))).unsqueeze(0).unsqueeze(0).cpu()

    def ER(self):
        if self.ddq and self.step % self.copy == 0:
            self.Q2.load_state_dict(self.Q1.state_dict())

        if self.mem_samp > self.num_que:
            return

        s1, s2, act, rew, done = self.rand_samp()
        s1 = s1.to(self.dev)
        s2 = s2.to(self.dev)
        act = act.to(self.dev)
        rew = rew.to(self.dev)
        done = done.to(self.dev)
        
        self.optimizer.zero_grad()
        
        if self.ddq:
            target = rew + torch.mul((self.gamma * self.Q2(s2).max(1).values.unsqueeze(1)), 1 - done)
        else:
            target = rew + torch.mul((self.gamma * self.Q1(s2).max(1).values.unsqueeze(1)), 1 - done)

        current = self.Q1(s1).gather(1, act.long())
        loss = self.loss(current, target)
        loss.backward()
        self.optimizer.step()
        self.erate *= self.decay
        if self.erate < self.emin:
          self.erate = self.emin

    def ER_data(self, s1, s2, act, rew, done):
        idx = self.end_pos

        self.memory[0][idx] = s1
        self.memory[1][idx] = s2
        self.memory[2][idx] = act
        self.memory[3][idx] = rew
        self.memory[4][idx] = done

        self.end_pos = (self.end_pos + 1) % self.max_mem
        self.num_que = min(self.num_que + 1, self.max_mem)
        
    def rand_samp(self):
        idx = random.choices(range(self.num_que), k=self.mem_samp)
        
        s1 = self.memory[0][idx]
        s2 = self.memory[1][idx]
        act = self.memory[2][idx]
        rew = self.memory[3][idx]
        done = self.memory[4][idx]
        
        return s1, s2, act, rew, done

# %%
def main():
    env = gym_super_mario_bros.make('SuperMarioBros-1-1-v0')
    env = proc_env(env)
    agent = Agent(s_space=env.obs_space.shape,a_space=env.action_space.n,
                  max_mem=30000,batch_size=32,erate=1.0,emin=0.00001,decay=0.999,lr=0.00025,gamma=0.90,ddq=False) #ddq = True or False
    PATH = '/content/drive/MyDrive/ModelParams_Eps_Decay_0.999_eps_1'
    rewards = []
    flag_pole_vec = []
    num_eps = 10000 #1000 # 10000
    

    for ep_num in range(num_eps):
        state = env.reset()
        state = torch.Tensor([state])
        tot_rew = 0
        idx = 0

        while True:
            act = agent.action(state,ep_num)
            idx += 1
            
            n_state, rew, term, info = env.step(int(act[0]))
            n_state = torch.Tensor([n_state])
            term = torch.tensor([int(term)])
            tot_rew += rew
            rew = torch.tensor([rew])

            agent.ER_data(state, n_state, act, rew, term)
            agent.ER()            
            state = n_state

            if term == 1:
                break
        flag_pole = 0
        if info['flag_get']:
          flag_pole = 1
          print('Level Completed')
        flag_pole_vec.append(flag_pole)
        rewards.append(tot_rew)

        if (ep_num + 1)%200 == 0:
          torch.save(agent.Q1.state_dict(), PATH)
        
        print("Total reward after episode {} is {}".format(ep_num + 1, rewards[-1]))
        num_eps += 1      

    if num_eps > 500:
        plt.figure(1)
        plt.title("Episodes trained vs. Average Rewards (per 500 eps)")
        plt.plot([0 for _ in range(500)] + 
                 np.convolve(rewards, np.ones((500,))/500, mode="valid").tolist())
        
        plt.figure(2)
        plt.title("Episodes trained vs. Win Percentage (per 500 eps)")
        plt.plot([0 for _ in range(500)] + 
                 np.convolve(flag_pole_vec, np.ones((500,))/500, mode="valid").tolist())
        plt.show()

main()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym_super_mario_bros/smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# Total reward after episode 1 is 609.0
# Total reward after episode 2 is 228.0
# Total reward after episode 3 is 629.0
# Total reward after episode 4 is 600.0
# Total reward after episode 5 is 209.0
# Total reward after episode 6 is 744.0
# Total reward after episode 7 is 1013.0
# Total reward after episode 8 is 1305.0
# Total reward after episode 9 is 230.0
# Total reward after episode 10 is 765.0
# Total reward after episode 11 is 230.0
# Total reward after episode 12 is 1026.0
# Total reward after episode 13 is 627.0
# Total reward after episode 14 is 627.0
# Total reward after episode 15 is 1043.0
# Total reward after episode 16 is 627.0
# Total reward after episode 17 is 231.0
# Total reward after episode 18 is 1031.0
# Total reward after episode 19 is 570.0
# Total reward after episode 20 is 231.0
# Total reward after episode 21 is 231.0
# Total reward after episode 22 is 602.0
# Total reward after episode 23 is 619.0
# Total reward after episode 24 is 665.0
# Total reward after episode 25 is 722.0
# Total reward after episode 26 is -131.0
# Total reward after episode 27 is 28.0
# Total reward after episode 28 is 267.0
# Total reward after episode 29 is 139.0
# Total reward after episode 30 is 231.0
# Total reward after episode 31 is 231.0
# Total reward after episode 32 is 267.0
# Total reward after episode 33 is 231.0
# Total reward after episode 34 is 754.0
# Total reward after episode 35 is 728.0
# Total reward after episode 36 is 231.0
# Total reward after episode 37 is 734.0
# Total reward after episode 38 is 749.0
# Total reward after episode 39 is 593.0
# Total reward after episode 40 is 585.0
# Total reward after episode 41 is 609.0
# Total reward after episode 42 is 224.0
# Total reward after episode 43 is 742.0
# Total reward after episode 44 is 760.0
# Total reward after episode 45 is 231.0
# Total reward after episode 46 is 231.0
# Total reward after episode 47 is 231.0
# Total reward after episode 48 is 622.0
# Total reward after episode 49 is 748.0
# Total reward after episode 50 is 231.0
# Total reward after episode 51 is 738.0
# Total reward after episode 52 is 231.0
# Total reward after episode 53 is 588.0
# Total reward after episode 54 is 231.0
# Total reward after episode 55 is 599.0
# Total reward after episode 56 is 231.0
# Total reward after episode 57 is 589.0
# Total reward after episode 58 is 139.0
# Total reward after episode 59 is 582.0
# Total reward after episode 60 is 1312.0
# Total reward after episode 61 is 231.0
# Total reward after episode 62 is 231.0
# Total reward after episode 63 is 231.0
# Total reward after episode 64 is 605.0
# Total reward after episode 65 is 185.0
# Total reward after episode 66 is 1265.0
# Total reward after episode 67 is 583.0
# Total reward after episode 68 is 1063.0
# Total reward after episode 69 is 231.0
# Total reward after episode 70 is 764.0
# Total reward after episode 71 is 231.0
# Total reward after episode 72 is 573.0
# Total reward after episode 73 is 1312.0
# Total reward after episode 74 is 231.0
# Total reward after episode 75 is 615.0
# Total reward after episode 76 is 580.0
# Total reward after episode 77 is 231.0
# Total reward after episode 78 is 693.0
# Total reward after episode 79 is 1190.0
# Total reward after episode 80 is 1028.0
# Total reward after episode 81 is 603.0
# Total reward after episode 82 is 787.0
# Total reward after episode 83 is 505.0
# Total reward after episode 84 is 810.0
# Total reward after episode 85 is 784.0
# Total reward after episode 86 is 139.0
# Total reward after episode 87 is 636.0
# Total reward after episode 88 is 618.0
# Total reward after episode 89 is -21.0
# Total reward after episode 90 is 618.0
# Total reward after episode 91 is 772.0
# Total reward after episode 92 is 1090.0
# Total reward after episode 93 is 547.0
# Total reward after episode 94 is 609.0
# Total reward after episode 95 is 1710.0
# Total reward after episode 96 is 1050.0
# Total reward after episode 97 is 778.0
# Total reward after episode 98 is 716.0
# Total reward after episode 99 is -131.0
# Total reward after episode 100 is 627.0
# Total reward after episode 101 is 606.0
# Total reward after episode 102 is 635.0
# Total reward after episode 103 is 811.0
# Total reward after episode 104 is 231.0
# Total reward after episode 105 is 811.0
# Total reward after episode 106 is 621.0
# Total reward after episode 107 is 231.0
# Total reward after episode 108 is 1291.0
# Total reward after episode 109 is 988.0
# Total reward after episode 110 is 1677.0
# Total reward after episode 111 is 957.0
# Total reward after episode 112 is 231.0
# Total reward after episode 113 is 962.0
# Total reward after episode 114 is 231.0
# Total reward after episode 115 is 810.0
# Total reward after episode 116 is 231.0
# Total reward after episode 117 is 231.0
# Total reward after episode 118 is 1404.0
# Total reward after episode 119 is 805.0
# Total reward after episode 120 is -140.0
# Total reward after episode 121 is -21.0
# Total reward after episode 122 is 960.0
# Total reward after episode 123 is 231.0
# Total reward after episode 124 is 462.0
# Total reward after episode 125 is 579.0
# Total reward after episode 126 is 629.0
# Total reward after episode 127 is 579.0
# Total reward after episode 128 is 231.0
# Total reward after episode 129 is 629.0
# Total reward after episode 130 is 754.0
# Total reward after episode 131 is 623.0
# Total reward after episode 132 is 231.0
# Total reward after episode 133 is 533.0
# Total reward after episode 134 is 231.0
# Total reward after episode 135 is 1424.0
# Total reward after episode 136 is 430.0
# Total reward after episode 137 is 1276.0
# Total reward after episode 138 is 231.0
# Total reward after episode 139 is 724.0
# Total reward after episode 140 is 1831.0
# Total reward after episode 141 is 231.0
# Total reward after episode 142 is 226.0
# Total reward after episode 143 is 635.0
# Total reward after episode 144 is 626.0
# Total reward after episode 145 is 231.0
# Total reward after episode 146 is 628.0
# Total reward after episode 147 is 800.0
# Total reward after episode 148 is 610.0
# Total reward after episode 149 is 231.0
# Total reward after episode 150 is 139.0
# Total reward after episode 151 is 226.0
# Total reward after episode 152 is 231.0
# Total reward after episode 153 is 749.0
# Total reward after episode 154 is 636.0
# Total reward after episode 155 is 480.0
# Total reward after episode 156 is 610.0
# Total reward after episode 157 is 774.0
# Total reward after episode 158 is 139.0
# Total reward after episode 159 is 139.0
# Total reward after episode 160 is 639.0
# Total reward after episode 161 is 1048.0
# Total reward after episode 162 is 626.0
# Total reward after episode 163 is 1083.0
# Total reward after episode 164 is 406.0
# Total reward after episode 165 is 759.0
# Total reward after episode 166 is 231.0
# Total reward after episode 167 is 231.0
# Total reward after episode 168 is 982.0
# Total reward after episode 169 is 231.0
# Total reward after episode 170 is 231.0
# Total reward after episode 171 is 689.0
# Total reward after episode 172 is 226.0
# Total reward after episode 173 is 231.0
# Total reward after episode 174 is 231.0
# Total reward after episode 175 is 626.0
# Total reward after episode 176 is 231.0
# Total reward after episode 177 is 231.0
# Total reward after episode 178 is 224.0
# Total reward after episode 179 is 228.0
# Total reward after episode 180 is 558.0
# Total reward after episode 181 is 809.0
# Total reward after episode 182 is 231.0
# Total reward after episode 183 is 231.0
# Total reward after episode 184 is 231.0
# Total reward after episode 185 is 810.0
# Total reward after episode 186 is 139.0
# Total reward after episode 187 is 616.0
# Total reward after episode 188 is 636.0
# Total reward after episode 189 is 805.0
# Total reward after episode 190 is 608.0
# Total reward after episode 191 is 231.0
# Total reward after episode 192 is 614.0
# Total reward after episode 193 is 231.0
# Total reward after episode 194 is 231.0
# Total reward after episode 195 is 1311.0
# Total reward after episode 196 is 532.0
# Total reward after episode 197 is 231.0
# Total reward after episode 198 is 231.0
# Total reward after episode 199 is 636.0
# Total reward after episode 200 is 611.0
# Total reward after episode 201 is 776.0
# Total reward after episode 202 is 614.0
# Total reward after episode 203 is 614.0
# Total reward after episode 204 is 231.0
# Total reward after episode 205 is 780.0
# Total reward after episode 206 is 809.0
# Total reward after episode 207 is 554.0
# Total reward after episode 208 is 231.0
# Total reward after episode 209 is 615.0
# Total reward after episode 210 is 1044.0
# Total reward after episode 211 is 231.0
# Total reward after episode 212 is 808.0
# Total reward after episode 213 is 615.0
# Total reward after episode 214 is 568.0
# Total reward after episode 215 is 231.0
# Total reward after episode 216 is 810.0
# Total reward after episode 217 is 613.0
# Total reward after episode 218 is 608.0
# Total reward after episode 219 is 811.0
# Total reward after episode 220 is 620.0
# Total reward after episode 221 is 610.0
# Total reward after episode 222 is 469.0
# Total reward after episode 223 is 615.0
# Total reward after episode 224 is 629.0
# Total reward after episode 225 is 627.0
# Total reward after episode 226 is 614.0
# Total reward after episode 227 is 636.0
# Total reward after episode 228 is 231.0
# Total reward after episode 229 is -21.0
# Total reward after episode 230 is 955.0
# Total reward after episode 231 is -21.0
# Total reward after episode 232 is 1309.0
# Total reward after episode 233 is 1276.0
# Total reward after episode 234 is 627.0
# Total reward after episode 235 is 812.0
# Total reward after episode 236 is 223.0
# Total reward after episode 237 is 810.0
# Total reward after episode 238 is 738.0
# Total reward after episode 239 is 139.0
# Total reward after episode 240 is 809.0
# Total reward after episode 241 is 635.0
# Total reward after episode 242 is 926.0
# Total reward after episode 243 is 804.0
# Total reward after episode 244 is 717.0
# Total reward after episode 245 is 627.0
# Total reward after episode 246 is 231.0
# Total reward after episode 247 is 626.0
# Total reward after episode 248 is 226.0
# Total reward after episode 249 is 977.0
# Total reward after episode 250 is 627.0
# Total reward after episode 251 is 139.0
# Total reward after episode 252 is 231.0
# Total reward after episode 253 is 139.0
# Total reward after episode 254 is 567.0
# Total reward after episode 255 is 231.0
# Total reward after episode 256 is 809.0
# Total reward after episode 257 is 231.0
# Total reward after episode 258 is 805.0
# Total reward after episode 259 is 1036.0
# Total reward after episode 260 is 231.0
# Total reward after episode 261 is 806.0
# Total reward after episode 262 is 1311.0
# Total reward after episode 263 is 443.0
# Total reward after episode 264 is 810.0
# Total reward after episode 265 is 810.0
# Total reward after episode 266 is 231.0
# Total reward after episode 267 is 231.0
# Total reward after episode 268 is 617.0
# Total reward after episode 269 is 616.0
# Total reward after episode 270 is 614.0
# Total reward after episode 271 is 231.0
# Total reward after episode 272 is 812.0
# Total reward after episode 273 is 169.0
# Total reward after episode 274 is 231.0
# Total reward after episode 275 is 231.0
# Total reward after episode 276 is 233.0
# Total reward after episode 277 is 231.0
# Total reward after episode 278 is 627.0
# Total reward after episode 279 is 231.0
# Total reward after episode 280 is 223.0
# Total reward after episode 281 is 691.0
# Total reward after episode 282 is 627.0
# Total reward after episode 283 is 231.0
# Total reward after episode 284 is 809.0
# Total reward after episode 285 is 1045.0
# Total reward after episode 286 is 617.0
# Total reward after episode 287 is 618.0
# Total reward after episode 288 is 231.0
# Total reward after episode 289 is 231.0
# Total reward after episode 290 is 231.0
# Total reward after episode 291 is 626.0
# Total reward after episode 292 is 139.0
# Total reward after episode 293 is -21.0
# Total reward after episode 294 is 231.0
# Total reward after episode 295 is 809.0
# Total reward after episode 296 is 732.0
# Total reward after episode 297 is 615.0
# Total reward after episode 298 is 226.0
# Total reward after episode 299 is 231.0
# Total reward after episode 300 is 809.0
# Total reward after episode 301 is 139.0
# Total reward after episode 302 is 231.0
# Total reward after episode 303 is 231.0
# Total reward after episode 304 is 231.0
# Total reward after episode 305 is 231.0
# Total reward after episode 306 is 139.0
# Total reward after episode 307 is 1049.0
# Total reward after episode 308 is 231.0
# Total reward after episode 309 is 226.0
# Total reward after episode 310 is 507.0
# Total reward after episode 311 is 626.0
# Total reward after episode 312 is 233.0
# Total reward after episode 313 is 1314.0
# Total reward after episode 314 is 139.0
# Total reward after episode 315 is 231.0
# Total reward after episode 316 is 139.0
# Total reward after episode 317 is 618.0
# Total reward after episode 318 is 139.0
# Total reward after episode 319 is 810.0
# Total reward after episode 320 is 231.0
# Total reward after episode 321 is 231.0
# Total reward after episode 322 is 139.0
# Total reward after episode 323 is 1037.0
# Total reward after episode 324 is 615.0
# Total reward after episode 325 is 1316.0
# Total reward after episode 326 is 1313.0
# Total reward after episode 327 is 186.0
# Total reward after episode 328 is 231.0
# Total reward after episode 329 is 812.0
# Total reward after episode 330 is 1410.0
# Total reward after episode 331 is 809.0
# Total reward after episode 332 is 810.0
# Total reward after episode 333 is 1126.0
# Total reward after episode 334 is 231.0
# Total reward after episode 335 is 231.0
# Total reward after episode 336 is 231.0
# Total reward after episode 337 is 256.0
# Total reward after episode 338 is 223.0
# Total reward after episode 339 is 615.0
# Total reward after episode 340 is 635.0
# Total reward after episode 341 is 625.0
# Total reward after episode 342 is 1410.0
# Total reward after episode 343 is 811.0
# Total reward after episode 344 is 636.0
# Total reward after episode 345 is 811.0
# Total reward after episode 346 is 626.0
# Total reward after episode 347 is 231.0
# Total reward after episode 348 is -21.0
# Total reward after episode 349 is 1308.0
# Total reward after episode 350 is 231.0
# Total reward after episode 351 is 1170.0
# Total reward after episode 352 is 686.0
# Total reward after episode 353 is 618.0
# Total reward after episode 354 is 139.0
# Total reward after episode 355 is 531.0
# Total reward after episode 356 is 810.0
# Total reward after episode 357 is 773.0
# Total reward after episode 358 is 1030.0
# Total reward after episode 359 is 1049.0
# Total reward after episode 360 is 626.0
# Total reward after episode 361 is 339.0
# Total reward after episode 362 is 1311.0
# Total reward after episode 363 is 1042.0
# Total reward after episode 364 is 809.0
# Total reward after episode 365 is 626.0
# Total reward after episode 366 is 420.0
# Total reward after episode 367 is 1042.0
# Total reward after episode 368 is 707.0
# Total reward after episode 369 is 1222.0
# Total reward after episode 370 is 231.0
# Total reward after episode 371 is 942.0
# Total reward after episode 372 is 624.0
# Total reward after episode 373 is 786.0
# Total reward after episode 374 is -21.0
# Total reward after episode 375 is 1046.0
# Total reward after episode 376 is 139.0
# Total reward after episode 377 is 580.0
# Total reward after episode 378 is 810.0
# Total reward after episode 379 is 636.0
# Total reward after episode 380 is 811.0
# Total reward after episode 381 is 139.0
# Total reward after episode 382 is 231.0
# Total reward after episode 383 is 139.0
# Total reward after episode 384 is 626.0
# Total reward after episode 385 is 636.0
# Total reward after episode 386 is 932.0
# Total reward after episode 387 is 378.0
# Total reward after episode 388 is 623.0
# Total reward after episode 389 is 626.0
# Total reward after episode 390 is 218.0
# Total reward after episode 391 is 223.0
# Total reward after episode 392 is 1318.0
# Total reward after episode 393 is 626.0
# Total reward after episode 394 is 231.0
# Total reward after episode 395 is 558.0
# Total reward after episode 396 is 223.0
# Total reward after episode 397 is 669.0
# Total reward after episode 398 is 490.0
# Total reward after episode 399 is 1316.0
# Total reward after episode 400 is 529.0
# Total reward after episode 401 is 628.0
# Total reward after episode 402 is 800.0
# Total reward after episode 403 is 363.0
# Total reward after episode 404 is 618.0
# Total reward after episode 405 is 139.0
# Total reward after episode 406 is 626.0
# Total reward after episode 407 is 241.0
# Total reward after episode 408 is 443.0
# Total reward after episode 409 is 1284.0
# Total reward after episode 410 is -21.0
# Total reward after episode 411 is -21.0
# Total reward after episode 412 is 231.0
# Total reward after episode 413 is 1313.0
# Total reward after episode 414 is 809.0
# Total reward after episode 415 is 809.0
# Total reward after episode 416 is 786.0
# Total reward after episode 417 is 614.0
# Total reward after episode 418 is 810.0
# Total reward after episode 419 is 734.0
# Total reward after episode 420 is 223.0
# Total reward after episode 421 is 139.0
# Total reward after episode 422 is 811.0
# Total reward after episode 423 is -21.0
# Total reward after episode 424 is 1552.0
# Total reward after episode 425 is 417.0
# Total reward after episode 426 is 231.0
# Total reward after episode 427 is 809.0
# Total reward after episode 428 is 231.0
# Total reward after episode 429 is 549.0
# Total reward after episode 430 is 723.0
# Total reward after episode 431 is 598.0
# Total reward after episode 432 is 231.0
# Total reward after episode 433 is -21.0
# Total reward after episode 434 is -21.0
# Total reward after episode 435 is -21.0
# Total reward after episode 436 is 231.0
# Total reward after episode 437 is 226.0
# Total reward after episode 438 is 231.0
# Total reward after episode 439 is 231.0
# Total reward after episode 440 is 231.0
# Total reward after episode 441 is 612.0
# Total reward after episode 442 is 1290.0
# Total reward after episode 443 is 614.0
# Total reward after episode 444 is -21.0
# Total reward after episode 445 is -21.0
# Total reward after episode 446 is 626.0
# Total reward after episode 447 is 231.0
# Total reward after episode 448 is 557.0
# Total reward after episode 449 is -21.0
# Total reward after episode 450 is 809.0
# Total reward after episode 451 is 231.0
# Total reward after episode 452 is 139.0
# Total reward after episode 453 is -21.0
# Total reward after episode 454 is 231.0
# Total reward after episode 455 is 231.0
# Total reward after episode 456 is 446.0
# Total reward after episode 457 is 231.0
# Total reward after episode 458 is 226.0
# Total reward after episode 459 is 231.0
# Total reward after episode 460 is 231.0
# Total reward after episode 461 is 231.0
# Total reward after episode 462 is 231.0
# Total reward after episode 463 is 231.0
# Total reward after episode 464 is 231.0
# Total reward after episode 465 is 447.0
# Total reward after episode 466 is 231.0
# Total reward after episode 467 is 510.0
# Total reward after episode 468 is 231.0
# Total reward after episode 469 is 231.0
# Total reward after episode 470 is 139.0
# Total reward after episode 471 is 139.0
# Total reward after episode 472 is 617.0
# Total reward after episode 473 is 1010.0
# Total reward after episode 474 is 231.0
# Total reward after episode 475 is 811.0
# Total reward after episode 476 is 267.0
# Total reward after episode 477 is 476.0
# Total reward after episode 478 is 518.0
# Total reward after episode 479 is 499.0
# Total reward after episode 480 is 139.0
# Total reward after episode 481 is 231.0
# Total reward after episode 482 is 933.0
# Total reward after episode 483 is 494.0
# Total reward after episode 484 is 810.0
# Total reward after episode 485 is 626.0
# Total reward after episode 486 is 617.0
# Total reward after episode 487 is 614.0
# Total reward after episode 488 is 297.0
# Total reward after episode 489 is 478.0
# Total reward after episode 490 is 769.0
# Total reward after episode 491 is 811.0
# Total reward after episode 492 is 612.0
# Total reward after episode 493 is 231.0
# Total reward after episode 494 is 231.0
# Total reward after episode 495 is 604.0
# Total reward after episode 496 is 623.0
# Total reward after episode 497 is 267.0
# Total reward after episode 498 is 279.0
# Total reward after episode 499 is 768.0
# Total reward after episode 500 is 618.0
# Total reward after episode 501 is 716.0
# Total reward after episode 502 is 1039.0
# Total reward after episode 503 is 697.0
# Total reward after episode 504 is 489.0
# Total reward after episode 505 is 618.0
# Total reward after episode 506 is 267.0
# Total reward after episode 507 is 933.0
# Total reward after episode 508 is 609.0
# Total reward after episode 509 is 267.0
# Total reward after episode 510 is 1036.0
# Total reward after episode 511 is 267.0
# Total reward after episode 512 is 231.0
# Total reward after episode 513 is 267.0
# Total reward after episode 514 is 231.0
# Total reward after episode 515 is 1292.0
# Total reward after episode 516 is 231.0
# Total reward after episode 517 is 1301.0
# Total reward after episode 518 is 567.0
# Total reward after episode 519 is 590.0
# Total reward after episode 520 is 267.0
# Total reward after episode 521 is 267.0
# Total reward after episode 522 is 139.0
# Total reward after episode 523 is -21.0
# Total reward after episode 524 is 589.0
# Total reward after episode 525 is 973.0
# Total reward after episode 526 is 231.0
# Total reward after episode 527 is 267.0
# Total reward after episode 528 is 226.0
# Total reward after episode 529 is 226.0
# Total reward after episode 530 is 313.0
# Total reward after episode 531 is -21.0
# Total reward after episode 532 is 1197.0
# Total reward after episode 533 is 231.0
# Total reward after episode 534 is 231.0
# Total reward after episode 535 is 1286.0
# Total reward after episode 536 is 622.0
# Total reward after episode 537 is 231.0
# Total reward after episode 538 is 231.0
# Total reward after episode 539 is 231.0
# Total reward after episode 540 is 276.0
# Total reward after episode 541 is 588.0
# Total reward after episode 542 is 267.0
# Total reward after episode 543 is 1313.0
# Total reward after episode 544 is 267.0
# Total reward after episode 545 is 231.0
# Total reward after episode 546 is 231.0
# Total reward after episode 547 is 267.0
# Total reward after episode 548 is 1311.0
# Total reward after episode 549 is 231.0
# Total reward after episode 550 is 267.0
# Total reward after episode 551 is 267.0
# Total reward after episode 552 is 231.0
# Total reward after episode 553 is 267.0
# Total reward after episode 554 is 231.0
# Total reward after episode 555 is 231.0
# Total reward after episode 556 is 231.0
# Total reward after episode 557 is 267.0
# Total reward after episode 558 is 231.0
# Total reward after episode 559 is 1311.0
# Total reward after episode 560 is 1038.0
# Total reward after episode 561 is 231.0
# Total reward after episode 562 is 1047.0
# Total reward after episode 563 is 231.0
# Total reward after episode 564 is 635.0
# Total reward after episode 565 is 231.0
# Total reward after episode 566 is 624.0
# Total reward after episode 567 is 231.0
# Total reward after episode 568 is 231.0
# Total reward after episode 569 is 610.0
# Total reward after episode 570 is 607.0
# Total reward after episode 571 is 231.0
# Total reward after episode 572 is 226.0
# Total reward after episode 573 is 231.0
# Total reward after episode 574 is 231.0
# Total reward after episode 575 is 810.0
# Total reward after episode 576 is 231.0
# Total reward after episode 577 is 1127.0
# Total reward after episode 578 is 1312.0
# Total reward after episode 579 is 231.0
# Total reward after episode 580 is 811.0
# Total reward after episode 581 is 231.0
# Total reward after episode 582 is 226.0
# Total reward after episode 583 is 231.0
# Total reward after episode 584 is 231.0
# Total reward after episode 585 is 231.0
# Total reward after episode 586 is 231.0
# Total reward after episode 587 is 231.0
# Total reward after episode 588 is 231.0
# Total reward after episode 589 is 231.0
# Total reward after episode 590 is 231.0
# Total reward after episode 591 is 1007.0
# Total reward after episode 592 is 231.0
# Total reward after episode 593 is 226.0
# Total reward after episode 594 is 1043.0
# Total reward after episode 595 is 231.0
# Total reward after episode 596 is 231.0
# Total reward after episode 597 is 231.0
# Total reward after episode 598 is 635.0
# Total reward after episode 599 is 226.0
# Total reward after episode 600 is 231.0
# Total reward after episode 601 is 635.0
# Total reward after episode 602 is 768.0
# Total reward after episode 603 is 231.0
# Total reward after episode 604 is 622.0
# Total reward after episode 605 is 231.0
# Total reward after episode 606 is 231.0
# Total reward after episode 607 is 231.0
# Total reward after episode 608 is 299.0
# Total reward after episode 609 is 636.0
# Total reward after episode 610 is 597.0
# Total reward after episode 611 is 231.0
# Total reward after episode 612 is 635.0
# Total reward after episode 613 is 226.0
# Total reward after episode 614 is 231.0
# Total reward after episode 615 is 635.0
# Total reward after episode 616 is 231.0
# Total reward after episode 617 is 139.0
# Total reward after episode 618 is 231.0
# Total reward after episode 619 is 604.0
# Total reward after episode 620 is 231.0
# Total reward after episode 621 is 231.0
# Total reward after episode 622 is 231.0
# Total reward after episode 623 is 231.0
# Total reward after episode 624 is 267.0
# Total reward after episode 625 is 231.0
# Total reward after episode 626 is 231.0
# Total reward after episode 627 is 635.0
# Total reward after episode 628 is 231.0
# Total reward after episode 629 is 620.0
# Total reward after episode 630 is 231.0
# Total reward after episode 631 is -21.0
# Total reward after episode 632 is 231.0
# Total reward after episode 633 is 231.0
# Total reward after episode 634 is 267.0
# Total reward after episode 635 is 1314.0
# Total reward after episode 636 is 169.0
# Total reward after episode 637 is 231.0
# Total reward after episode 638 is 231.0
# Total reward after episode 639 is 636.0
# Total reward after episode 640 is 231.0
# Total reward after episode 641 is 231.0
# Total reward after episode 642 is 231.0
# Total reward after episode 643 is 635.0
# Total reward after episode 644 is 231.0
# Total reward after episode 645 is 738.0
# Total reward after episode 646 is 690.0
# Total reward after episode 647 is 629.0
# Total reward after episode 648 is -21.0
# Total reward after episode 649 is 224.0
# Total reward after episode 650 is 587.0
# Total reward after episode 651 is 215.0
# Total reward after episode 652 is 217.0
# Total reward after episode 653 is 215.0
# Total reward after episode 654 is 231.0
# Total reward after episode 655 is 231.0
# Total reward after episode 656 is 338.0
# Total reward after episode 657 is 1313.0
# Total reward after episode 658 is 231.0
# Total reward after episode 659 is 634.0
# Total reward after episode 660 is 799.0
# Total reward after episode 661 is 215.0
# Total reward after episode 662 is 231.0
# Total reward after episode 663 is 231.0
# Total reward after episode 664 is 411.0
# Total reward after episode 665 is 231.0
# Total reward after episode 666 is 217.0
# Total reward after episode 667 is 623.0
# Total reward after episode 668 is 267.0
# Total reward after episode 669 is 231.0
# Total reward after episode 670 is 215.0
# Total reward after episode 671 is 768.0
# Total reward after episode 672 is 223.0
# Total reward after episode 673 is 217.0
# Total reward after episode 674 is 222.0
# Total reward after episode 675 is 231.0
# Total reward after episode 676 is 139.0
# Total reward after episode 677 is 231.0
# Total reward after episode 678 is 231.0
# Total reward after episode 679 is 231.0
# Total reward after episode 680 is 909.0
# Total reward after episode 681 is 231.0
# Total reward after episode 682 is 1182.0
# Total reward after episode 683 is 1299.0
# Total reward after episode 684 is 231.0
# Total reward after episode 685 is 231.0
# Total reward after episode 686 is 231.0
# Total reward after episode 687 is 222.0
# Total reward after episode 688 is 811.0
# Total reward after episode 689 is 231.0
# Total reward after episode 690 is 634.0
# Total reward after episode 691 is 223.0
# Total reward after episode 692 is 231.0
# Total reward after episode 693 is 231.0
# Total reward after episode 694 is 231.0
# Total reward after episode 695 is 610.0
# Total reward after episode 696 is 231.0
# Total reward after episode 697 is 267.0
# Total reward after episode 698 is 231.0
# Total reward after episode 699 is 231.0
# Total reward after episode 700 is 231.0
# Total reward after episode 701 is 231.0
# Total reward after episode 702 is 231.0
# Total reward after episode 703 is 231.0
# Total reward after episode 704 is 231.0
# Total reward after episode 705 is 231.0
# Total reward after episode 706 is 231.0
# Total reward after episode 707 is 231.0
# Total reward after episode 708 is 226.0
# Total reward after episode 709 is 231.0
# Total reward after episode 710 is 226.0
# Total reward after episode 711 is 1049.0
# Total reward after episode 712 is 231.0
# Total reward after episode 713 is 231.0
# Total reward after episode 714 is 729.0
# Total reward after episode 715 is 231.0
# Total reward after episode 716 is 626.0
# Total reward after episode 717 is 636.0
# Total reward after episode 718 is 231.0
# Total reward after episode 719 is 231.0
# Total reward after episode 720 is 231.0
# Total reward after episode 721 is 231.0
# Total reward after episode 722 is 231.0
# Total reward after episode 723 is 226.0
# Total reward after episode 724 is 231.0
# Total reward after episode 725 is 660.0
# Total reward after episode 726 is 231.0
# Total reward after episode 727 is 231.0
# Total reward after episode 728 is 231.0
# Total reward after episode 729 is 231.0
# Total reward after episode 730 is 226.0
# Total reward after episode 731 is 223.0
# Total reward after episode 732 is 384.0
# Total reward after episode 733 is 231.0
# Total reward after episode 734 is 225.0
# Total reward after episode 735 is 231.0
# Total reward after episode 736 is 231.0
# Total reward after episode 737 is 231.0
# Total reward after episode 738 is 231.0
# Total reward after episode 739 is 231.0
# Total reward after episode 740 is 231.0
# Total reward after episode 741 is 231.0
# Total reward after episode 742 is 231.0
# Total reward after episode 743 is 797.0
# Total reward after episode 744 is 623.0
# Total reward after episode 745 is 808.0
# Total reward after episode 746 is 225.0
# Total reward after episode 747 is 618.0
# Total reward after episode 748 is 231.0
# Total reward after episode 749 is 231.0
# Total reward after episode 750 is 225.0
# Total reward after episode 751 is 231.0
# Total reward after episode 752 is 231.0
# Total reward after episode 753 is 231.0
# Total reward after episode 754 is 225.0
# Total reward after episode 755 is 226.0
# Total reward after episode 756 is 226.0
# Total reward after episode 757 is 231.0
# Total reward after episode 758 is 231.0
# Total reward after episode 759 is 226.0
# Total reward after episode 760 is 226.0
# Total reward after episode 761 is 226.0
# Total reward after episode 762 is 557.0
# Total reward after episode 763 is 231.0
# Total reward after episode 764 is 231.0
# Total reward after episode 765 is 226.0
# Total reward after episode 766 is 231.0
# Total reward after episode 767 is 626.0
# Total reward after episode 768 is 226.0
# Total reward after episode 769 is 226.0
# Total reward after episode 770 is 231.0
# Total reward after episode 771 is 231.0
# Total reward after episode 772 is 226.0
# Total reward after episode 773 is 231.0
# Total reward after episode 774 is 231.0
# Total reward after episode 775 is 231.0
# Total reward after episode 776 is 231.0
# Total reward after episode 777 is 231.0
# Total reward after episode 778 is 226.0
# Total reward after episode 779 is 231.0
# Total reward after episode 780 is 231.0
# Total reward after episode 781 is 231.0
# Total reward after episode 782 is 231.0
# Total reward after episode 783 is 231.0
# Total reward after episode 784 is 231.0
# Total reward after episode 785 is 231.0
# Total reward after episode 786 is 226.0
# Total reward after episode 787 is 231.0
# Total reward after episode 788 is 231.0
# Total reward after episode 789 is 231.0
# Total reward after episode 790 is 231.0
# Total reward after episode 791 is 231.0
# Total reward after episode 792 is 231.0
# Total reward after episode 793 is 231.0
# Total reward after episode 794 is 223.0
# Total reward after episode 795 is 226.0
# Total reward after episode 796 is 231.0
# Total reward after episode 797 is 226.0
# Total reward after episode 798 is 231.0
# Total reward after episode 799 is 231.0
# Total reward after episode 800 is 231.0
# Total reward after episode 801 is 267.0
# Total reward after episode 802 is 770.0
# Total reward after episode 803 is 231.0
# Total reward after episode 804 is 231.0
# Total reward after episode 805 is 812.0
# Total reward after episode 806 is 401.0
# Total reward after episode 807 is 231.0
# Total reward after episode 808 is 231.0
# Total reward after episode 809 is 231.0
# Total reward after episode 810 is 231.0
# Total reward after episode 811 is 231.0
# Total reward after episode 812 is 231.0
# Total reward after episode 813 is 636.0
# Total reward after episode 814 is 231.0
# Total reward after episode 815 is 226.0
# Total reward after episode 816 is 231.0
# Total reward after episode 817 is 231.0
# Total reward after episode 818 is 231.0
# Total reward after episode 819 is 231.0
# Total reward after episode 820 is 644.0
# Total reward after episode 821 is 226.0
# Total reward after episode 822 is 443.0
# Total reward after episode 823 is 778.0
# Total reward after episode 824 is 231.0
# Total reward after episode 825 is 231.0
# Total reward after episode 826 is 231.0
# Total reward after episode 827 is 226.0
# Total reward after episode 828 is 226.0
# Total reward after episode 829 is 231.0
# Total reward after episode 830 is 231.0
# Total reward after episode 831 is 231.0
# Total reward after episode 832 is 231.0
# Total reward after episode 833 is 231.0
# Total reward after episode 834 is 226.0
# Total reward after episode 835 is 636.0
# Total reward after episode 836 is 231.0
# Total reward after episode 837 is 231.0
# Total reward after episode 838 is 223.0
# Total reward after episode 839 is 231.0
# Total reward after episode 840 is 231.0
# Total reward after episode 841 is 231.0
# Total reward after episode 842 is 231.0
# Total reward after episode 843 is 811.0
# Total reward after episode 844 is 223.0
# Total reward after episode 845 is 231.0
# Total reward after episode 846 is 231.0
# Total reward after episode 847 is 597.0
# Total reward after episode 848 is 231.0
# Total reward after episode 849 is 675.0
# Total reward after episode 850 is 231.0
# Total reward after episode 851 is 231.0
# Total reward after episode 852 is 231.0
# Total reward after episode 853 is 231.0
# Total reward after episode 854 is 231.0
# Total reward after episode 855 is 1047.0
# Total reward after episode 856 is 231.0
# Total reward after episode 857 is 226.0
# Total reward after episode 858 is 231.0
# Total reward after episode 859 is 231.0
# Total reward after episode 860 is 626.0
# Total reward after episode 861 is 231.0
# Total reward after episode 862 is 231.0
# Total reward after episode 863 is 231.0
# Total reward after episode 864 is 231.0
# Total reward after episode 865 is 231.0
# Total reward after episode 866 is 231.0
# Total reward after episode 867 is 635.0
# Total reward after episode 868 is 226.0
# Total reward after episode 869 is 231.0
# Total reward after episode 870 is 231.0
# Total reward after episode 871 is 231.0
# Total reward after episode 872 is 231.0
# Total reward after episode 873 is 231.0
# Total reward after episode 874 is 226.0
# Total reward after episode 875 is 231.0
# Total reward after episode 876 is 231.0
# Total reward after episode 877 is 223.0
# Total reward after episode 878 is 231.0
# Total reward after episode 879 is 231.0
# Total reward after episode 880 is 231.0
# Total reward after episode 881 is 231.0
# Total reward after episode 882 is 139.0
# Total reward after episode 883 is 910.0
# Total reward after episode 884 is 779.0
# Total reward after episode 885 is 231.0
# Total reward after episode 886 is 231.0
# Total reward after episode 887 is 231.0
# Total reward after episode 888 is 231.0
# Total reward after episode 889 is 231.0
# Total reward after episode 890 is 231.0
# Total reward after episode 891 is 231.0
# Total reward after episode 892 is 231.0
# Total reward after episode 893 is 226.0
# Total reward after episode 894 is 231.0
# Total reward after episode 895 is 231.0
# Total reward after episode 896 is 231.0
# Total reward after episode 897 is 226.0
# Total reward after episode 898 is 231.0
# Total reward after episode 899 is 1006.0
# Total reward after episode 900 is 1038.0
# Total reward after episode 901 is 231.0
# Total reward after episode 902 is 1029.0
# Total reward after episode 903 is 231.0
# Total reward after episode 904 is 231.0
# Total reward after episode 905 is 1313.0
# Total reward after episode 906 is 231.0
# Total reward after episode 907 is 231.0
# Total reward after episode 908 is 1312.0
# Total reward after episode 909 is 231.0
# Total reward after episode 910 is 231.0
# Total reward after episode 911 is 1409.0
# Total reward after episode 912 is 231.0
# Total reward after episode 913 is 231.0
# Total reward after episode 914 is 225.0
# Total reward after episode 915 is 230.0
# Total reward after episode 916 is 231.0
# Total reward after episode 917 is 231.0
# Total reward after episode 918 is 230.0
# Total reward after episode 919 is 231.0
# Total reward after episode 920 is 231.0
# Total reward after episode 921 is 231.0
# Total reward after episode 922 is 231.0
# Total reward after episode 923 is 231.0
# Total reward after episode 924 is 231.0
# Total reward after episode 925 is 1014.0
# Total reward after episode 926 is 231.0
# Total reward after episode 927 is 223.0
# Total reward after episode 928 is 231.0
# Total reward after episode 929 is 1010.0
# Total reward after episode 930 is 1292.0
# Total reward after episode 931 is 225.0
# Total reward after episode 932 is 1308.0
# Total reward after episode 933 is 548.0
# Total reward after episode 934 is 624.0
# Total reward after episode 935 is 231.0
# Total reward after episode 936 is 231.0
# Total reward after episode 937 is 1407.0
# Total reward after episode 938 is 231.0
# Total reward after episode 939 is 231.0
# Total reward after episode 940 is 231.0
# Total reward after episode 941 is 1313.0
# Total reward after episode 942 is 231.0
# Total reward after episode 943 is 231.0
# Total reward after episode 944 is 231.0
# Total reward after episode 945 is 231.0
# Total reward after episode 946 is 231.0
# Total reward after episode 947 is 231.0
# Total reward after episode 948 is 231.0
# Total reward after episode 949 is 231.0
# Total reward after episode 950 is 231.0
# Total reward after episode 951 is 230.0
# Total reward after episode 952 is 1133.0
# Total reward after episode 953 is 1043.0
# Total reward after episode 954 is 626.0
# Total reward after episode 955 is 231.0
# Total reward after episode 956 is 231.0
# Total reward after episode 957 is 231.0
# Total reward after episode 958 is 231.0
# Total reward after episode 959 is 231.0
# Total reward after episode 960 is 267.0
# Total reward after episode 961 is 231.0
# Total reward after episode 962 is 231.0
# Total reward after episode 963 is 231.0
# Total reward after episode 964 is 231.0
# Total reward after episode 965 is 231.0
# Total reward after episode 966 is 231.0
# Total reward after episode 967 is 231.0
# Total reward after episode 968 is 1407.0
# Total reward after episode 969 is 231.0
# Total reward after episode 970 is 221.0
# Total reward after episode 971 is 231.0
# Total reward after episode 972 is 231.0
# Total reward after episode 973 is 231.0
# Total reward after episode 974 is 225.0
# Total reward after episode 975 is 231.0
# Total reward after episode 976 is 231.0
# Total reward after episode 977 is 231.0
# Total reward after episode 978 is 231.0
# Total reward after episode 979 is 231.0
# Total reward after episode 980 is 231.0
# Total reward after episode 981 is 601.0
# Total reward after episode 982 is 231.0
# Total reward after episode 983 is 231.0
# Total reward after episode 984 is 231.0
# Total reward after episode 985 is 636.0
# Total reward after episode 986 is 231.0
# Total reward after episode 987 is 231.0
# Total reward after episode 988 is 225.0
# Total reward after episode 989 is 231.0
# Total reward after episode 990 is 231.0
# Total reward after episode 991 is 231.0
# Total reward after episode 992 is 784.0
# Total reward after episode 993 is 231.0
# Total reward after episode 994 is 231.0
# Total reward after episode 995 is 231.0
# Total reward after episode 996 is 231.0
# Total reward after episode 997 is 1307.0
# Total reward after episode 998 is 231.0
# Total reward after episode 999 is 231.0
# Total reward after episode 1000 is 231.0
# Total reward after episode 1001 is 1311.0
# Total reward after episode 1002 is 231.0
# Total reward after episode 1003 is 231.0
# Total reward after episode 1004 is 231.0
# Total reward after episode 1005 is 231.0
# Total reward after episode 1006 is 1014.0
# Total reward after episode 1007 is 568.0
# Total reward after episode 1008 is 636.0
# Total reward after episode 1009 is 231.0
# Total reward after episode 1010 is 216.0
# Total reward after episode 1011 is 231.0
# Total reward after episode 1012 is 592.0
# Total reward after episode 1013 is 231.0
# Total reward after episode 1014 is 231.0
# Total reward after episode 1015 is 231.0
# Total reward after episode 1016 is 1314.0
# Total reward after episode 1017 is 797.0
# Total reward after episode 1018 is 231.0
# Total reward after episode 1019 is 231.0
# Total reward after episode 1020 is 231.0
# Total reward after episode 1021 is 231.0
# Total reward after episode 1022 is 231.0
# Total reward after episode 1023 is 1323.0
# Total reward after episode 1024 is 231.0
# Total reward after episode 1025 is 231.0
# Total reward after episode 1026 is 231.0
# Total reward after episode 1027 is 231.0
# Total reward after episode 1028 is 588.0
# Total reward after episode 1029 is 231.0
# Total reward after episode 1030 is 231.0
# Total reward after episode 1031 is 784.0
# Total reward after episode 1032 is 231.0
# Total reward after episode 1033 is 231.0
# Total reward after episode 1034 is 231.0
# Total reward after episode 1035 is 231.0
# Total reward after episode 1036 is 231.0
# Total reward after episode 1037 is 231.0
# Total reward after episode 1038 is 231.0
# Total reward after episode 1039 is 1083.0
# Total reward after episode 1040 is 231.0
# Total reward after episode 1041 is 231.0
# Total reward after episode 1042 is 225.0
# Total reward after episode 1043 is 223.0
# Total reward after episode 1044 is 230.0
# Total reward after episode 1045 is 1172.0
# Total reward after episode 1046 is -21.0
# Total reward after episode 1047 is 223.0
# Total reward after episode 1048 is 230.0
# Total reward after episode 1049 is 230.0
# Total reward after episode 1050 is 230.0
# Total reward after episode 1051 is 230.0
# Total reward after episode 1052 is -21.0
# Total reward after episode 1053 is 230.0
# Total reward after episode 1054 is 230.0
# Total reward after episode 1055 is 230.0
# Total reward after episode 1056 is 230.0
# Total reward after episode 1057 is 230.0
# Total reward after episode 1058 is 230.0
# Total reward after episode 1059 is -29.0
# Total reward after episode 1060 is 231.0
# Total reward after episode 1061 is 230.0
# Total reward after episode 1062 is 314.0
# Total reward after episode 1063 is 424.0
# Total reward after episode 1064 is 231.0
# Total reward after episode 1065 is 880.0
# Total reward after episode 1066 is 118.0
# Total reward after episode 1067 is 231.0
# Total reward after episode 1068 is 530.0
# Total reward after episode 1069 is 231.0
# Total reward after episode 1070 is 1544.0
# Total reward after episode 1071 is 506.0
# Total reward after episode 1072 is 231.0
# Total reward after episode 1073 is 1042.0
# Total reward after episode 1074 is 231.0
# Total reward after episode 1075 is 231.0
# Total reward after episode 1076 is 965.0
# Total reward after episode 1077 is 246.0
# Total reward after episode 1078 is 187.0
# Total reward after episode 1079 is -24.0
# Total reward after episode 1080 is 231.0
# Total reward after episode 1081 is -25.0
# Total reward after episode 1082 is 801.0
# Total reward after episode 1083 is 413.0
# Total reward after episode 1084 is 810.0
# Total reward after episode 1085 is 230.0
# Total reward after episode 1086 is 159.0
# Total reward after episode 1087 is 231.0
# Total reward after episode 1088 is 231.0
# Total reward after episode 1089 is 231.0
# Total reward after episode 1090 is 1315.0
# Total reward after episode 1091 is 162.0
# Total reward after episode 1092 is 1313.0
# Total reward after episode 1093 is 1553.0
# Total reward after episode 1094 is 1049.0
# Total reward after episode 1095 is 1094.0
# Total reward after episode 1096 is 231.0
# Total reward after episode 1097 is 231.0
# Total reward after episode 1098 is 808.0
# Total reward after episode 1099 is 231.0
# Total reward after episode 1100 is 739.0
# Total reward after episode 1101 is 628.0
# Total reward after episode 1102 is 443.0
# Total reward after episode 1103 is 231.0
# Total reward after episode 1104 is 231.0
# Total reward after episode 1105 is 231.0
# Total reward after episode 1106 is 231.0
# Total reward after episode 1107 is 231.0
# Total reward after episode 1108 is 231.0
# Total reward after episode 1109 is 231.0
# Total reward after episode 1110 is 231.0
# Total reward after episode 1111 is 231.0
# Total reward after episode 1112 is 231.0
# Total reward after episode 1113 is 231.0
# Total reward after episode 1114 is 231.0
# Total reward after episode 1115 is -21.0
# Total reward after episode 1116 is 231.0
# Total reward after episode 1117 is 231.0
# Total reward after episode 1118 is 231.0
# Total reward after episode 1119 is 636.0
# Total reward after episode 1120 is 231.0
# Total reward after episode 1121 is 225.0
# Total reward after episode 1122 is 139.0
# Total reward after episode 1123 is 231.0
# Total reward after episode 1124 is 231.0
# Total reward after episode 1125 is -21.0
# Total reward after episode 1126 is 941.0
# Total reward after episode 1127 is 231.0
# Total reward after episode 1128 is 231.0
# Total reward after episode 1129 is 231.0
# Total reward after episode 1130 is 231.0
# Total reward after episode 1131 is 231.0
# Total reward after episode 1132 is 231.0
# Total reward after episode 1133 is 231.0
# Total reward after episode 1134 is 231.0
# Total reward after episode 1135 is 53.0
# Total reward after episode 1136 is 231.0
# Total reward after episode 1137 is 718.0
# Total reward after episode 1138 is 791.0
# Total reward after episode 1139 is 231.0
# Total reward after episode 1140 is 626.0
# Total reward after episode 1141 is 1131.0
# Total reward after episode 1142 is 231.0
# Total reward after episode 1143 is 231.0
# Total reward after episode 1144 is 231.0
# Total reward after episode 1145 is 810.0
# Total reward after episode 1146 is 636.0
# Total reward after episode 1147 is 810.0
# Total reward after episode 1148 is 231.0
# Total reward after episode 1149 is 231.0
# Total reward after episode 1150 is 231.0
# Total reward after episode 1151 is 231.0
# Total reward after episode 1152 is 231.0
# Total reward after episode 1153 is 231.0
# Total reward after episode 1154 is 636.0
# Total reward after episode 1155 is 636.0
# Total reward after episode 1156 is 231.0
# Total reward after episode 1157 is 231.0
# Total reward after episode 1158 is 626.0
# Total reward after episode 1159 is 231.0
# Total reward after episode 1160 is 231.0
# Total reward after episode 1161 is 231.0
# Total reward after episode 1162 is 751.0
# Total reward after episode 1163 is 1115.0
# Total reward after episode 1164 is 231.0
# Total reward after episode 1165 is 812.0
# Total reward after episode 1166 is 231.0
# Total reward after episode 1167 is 231.0
# Total reward after episode 1168 is 216.0
# Total reward after episode 1169 is 230.0
# Total reward after episode 1170 is 636.0
# Total reward after episode 1171 is 1037.0
# Total reward after episode 1172 is 228.0
# Total reward after episode 1173 is 629.0
# Total reward after episode 1174 is 228.0
# Total reward after episode 1175 is 636.0
# Total reward after episode 1176 is 636.0
# Total reward after episode 1177 is 139.0
# Total reward after episode 1178 is 557.0
# Total reward after episode 1179 is 809.0
# Total reward after episode 1180 is 228.0
# Total reward after episode 1181 is 224.0
# Total reward after episode 1182 is 597.0
# Total reward after episode 1183 is 582.0
# Total reward after episode 1184 is 220.0
# Total reward after episode 1185 is 220.0
# Total reward after episode 1186 is 220.0
# Total reward after episode 1187 is 220.0
# Total reward after episode 1188 is 785.0
# Total reward after episode 1189 is 230.0
# Total reward after episode 1190 is 636.0
# Total reward after episode 1191 is 267.0
# Total reward after episode 1192 is 811.0
# Total reward after episode 1193 is 1041.0
# Total reward after episode 1194 is 485.0
# Total reward after episode 1195 is 1323.0
# Total reward after episode 1196 is 443.0
# Total reward after episode 1197 is 1279.0
# Total reward after episode 1198 is 1047.0
# Total reward after episode 1199 is 1114.0
# Total reward after episode 1200 is 230.0
# Total reward after episode 1201 is 230.0
# Total reward after episode 1202 is 1284.0
# Total reward after episode 1203 is 626.0
# Total reward after episode 1204 is 628.0
# Total reward after episode 1205 is 810.0
# Total reward after episode 1206 is 597.0
# Total reward after episode 1207 is 811.0
# Total reward after episode 1208 is 626.0
# Total reward after episode 1209 is 810.0
# Total reward after episode 1210 is 1103.0
# Total reward after episode 1211 is 798.0
# Total reward after episode 1212 is 626.0
# Total reward after episode 1213 is 1128.0
# Total reward after episode 1214 is 625.0
# Total reward after episode 1215 is 616.0
# Total reward after episode 1216 is 811.0
# Total reward after episode 1217 is 230.0
# Total reward after episode 1218 is 626.0
# Total reward after episode 1219 is 811.0
# Total reward after episode 1220 is 811.0
# Total reward after episode 1221 is 230.0
# Total reward after episode 1222 is 811.0
# Total reward after episode 1223 is 1021.0
# Total reward after episode 1224 is 267.0
# Total reward after episode 1225 is 1409.0
# Total reward after episode 1226 is 1127.0
# Total reward after episode 1227 is 1410.0
# Total reward after episode 1228 is 627.0
# Total reward after episode 1229 is 811.0
# Total reward after episode 1230 is 1409.0
# Total reward after episode 1231 is 1048.0
# Total reward after episode 1232 is 797.0
# Total reward after episode 1233 is 803.0
# Total reward after episode 1234 is 205.0
# Total reward after episode 1235 is 231.0
# Total reward after episode 1236 is 196.0
# Total reward after episode 1237 is 811.0
# Total reward after episode 1238 is 231.0
# Total reward after episode 1239 is 409.0
# Total reward after episode 1240 is -21.0
# Total reward after episode 1241 is 230.0
# Total reward after episode 1242 is 230.0
# Total reward after episode 1243 is 616.0
# Total reward after episode 1244 is 633.0
# Total reward after episode 1245 is 1001.0
# Total reward after episode 1246 is 977.0
# Total reward after episode 1247 is -21.0
# Total reward after episode 1248 is 231.0
# Total reward after episode 1249 is 231.0
# Total reward after episode 1250 is 811.0
# Total reward after episode 1251 is 1263.0
# Total reward after episode 1252 is 230.0
# Total reward after episode 1253 is 1409.0
# Total reward after episode 1254 is 126.0
# Total reward after episode 1255 is 231.0
# Total reward after episode 1256 is 231.0
# Total reward after episode 1257 is 230.0
# Total reward after episode 1258 is 811.0
# Total reward after episode 1259 is 231.0
# Total reward after episode 1260 is 231.0
# Total reward after episode 1261 is 231.0
# Total reward after episode 1262 is -21.0
# Total reward after episode 1263 is 231.0
# Total reward after episode 1264 is 231.0
# Total reward after episode 1265 is 629.0
# Total reward after episode 1266 is 230.0
# Total reward after episode 1267 is 1549.0
# Total reward after episode 1268 is 231.0
# Total reward after episode 1269 is 810.0
# Total reward after episode 1270 is 230.0
# Total reward after episode 1271 is 231.0
# Total reward after episode 1272 is 231.0
# Total reward after episode 1273 is 231.0
# Total reward after episode 1274 is 139.0
# Total reward after episode 1275 is 230.0
# Total reward after episode 1276 is 231.0
# Total reward after episode 1277 is 231.0
# Total reward after episode 1278 is 805.0
# Total reward after episode 1279 is 810.0
# Total reward after episode 1280 is 231.0
# Total reward after episode 1281 is 139.0
# Total reward after episode 1282 is 231.0
# Total reward after episode 1283 is 231.0
# Total reward after episode 1284 is 267.0
# Total reward after episode 1285 is 231.0
# Total reward after episode 1286 is 231.0
# Total reward after episode 1287 is 1376.0
# Total reward after episode 1288 is 231.0
# Total reward after episode 1289 is 225.0
# Total reward after episode 1290 is 230.0
# Total reward after episode 1291 is 629.0
# Total reward after episode 1292 is 231.0
# Total reward after episode 1293 is 231.0
# Total reward after episode 1294 is 628.0
# Total reward after episode 1295 is 782.0
# Total reward after episode 1296 is 735.0
# Total reward after episode 1297 is 231.0
# Total reward after episode 1298 is 231.0
# Total reward after episode 1299 is 139.0
# Total reward after episode 1300 is 981.0
# Total reward after episode 1301 is 797.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-99e56446f02d> in <module>()
#      57         plt.show()
#      58
# ---> 59 main()
#
# <ipython-input-6-99e56446f02d> in main()
#      27
#      28             agent.ER_data(state, n_state, act, rew, term)
# ---> 29             agent.ER()
#      30             state = n_state
#      31
#
# <ipython-input-5-5d9080995925> in ER(self)
#      81             target = rew + torch.mul((self.gamma * self.Q1(s2).max(1).values.unsqueeze(1)), 1 - done)
#      82
# ---> 83         current = self.Q1(s1).gather(1, act.long())
#      84         loss = self.loss(current, target)
#      85         loss.backward()
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-5-5d9080995925> in forward(self, x)
#      17
#      18     def forward(self, x):
# ---> 19         conv_out = self.conv(x)
#      20         return conv_out
#      21
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     397
#     398     def forward(self, input: Tensor) -> Tensor:
# --> 399         return self._conv_forward(input, self.weight, self.bias)
#     400
#     401 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     394                             _pair(0), self.dilation, self.groups)
#     395         return F.conv2d(input, weight, bias, self.stride,
# --> 396                         self.padding, self.dilation, self.groups)
#     397
#     398     def forward(self, input: Tensor) -> Tensor:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Load Latest Model

# %%
model_save_name = 'Latest_Model_v2.pt'
path = F"/content/gdrive/MyDrive/Model Save Folder/{model_save_name}"
env = gym_super_mario_bros.make('SuperMarioBros-1-1-v0')
env = proc_env(env)
agent = Agent(s_space=env.obs_space.shape,a_space=env.action_space.n,
                  max_mem=30000,batch_size=32,erate=0,emin=0,decay=0.99,lr=0.00025,gamma=0.90,ddq=True) 
agent.Q1.load_state_dict(torch.load(path))

# %%
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
from IPython import display as ipythondisplay
from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start()

env = gym_super_mario_bros.make('SuperMarioBros-2-1-v0')
env = proc_env(env)
state = env.reset()
state = torch.Tensor([state])
tot_rew = 0
idx = 0

while True:
    act = agent.action_best(state)
    idx += 1
    
    n_state, rew, term, info = env.step(int(act[0]))
    n_state = torch.Tensor([n_state])
    term = torch.tensor([int(term)])
    tot_rew += rew
    rew = torch.tensor([rew])

    agent.ER_data(state, n_state, act, rew, term)
    agent.ER()            
    state = n_state
    screen = env.render(mode='rgb_array')
    plt.imshow(screen)
    ipythondisplay.clear_output(wait=True)
    ipythondisplay.display(plt.gcf())

    if term == 1:
        break
flag_pole = 0
if info['flag_get']:
  flag_pole = 1
  print('Level Competion')


print("Total reward is {}".format(rew))
